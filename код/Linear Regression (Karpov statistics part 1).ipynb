# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
url = 'http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv'
df = pd.read_csv(url)
df
# Out:
#                     state  metro_res  white  hs_grad  poverty  female_house
# 0                 Alabama       55.4   71.3     79.9     14.6          14.2
# 1                  Alaska       65.6   70.8     90.6      8.3          10.8
# 2                 Arizona       88.2   87.7     83.8     13.3          11.1
# 3                Arkansas       52.5   81.0     80.9     18.0          12.1
# 4              California       94.4   77.5     81.1     12.8          12.6
# 5                Colorado       84.5   90.2     88.7      9.4           9.6
# 6             Connecticut       87.7   85.4     87.5      7.8          12.1
# 7                Delaware       80.1   76.3     88.7      8.1          13.1
# 8   District  of Columbia      100.0   36.2     86.0     16.8          18.9
# 9                 Florida       89.3   80.6     84.7     12.1          12.0
# 10                Georgia       71.6   67.5     85.1     12.1          14.5
# ...

# %%
df[['hs_grad', 'poverty']].describe()
# Out:
#          hs_grad    poverty
# count  51.000000  51.000000
# mean   86.011765  11.349020
# std     3.725998   3.099185
# min    77.200000   5.600000
# 25%    83.300000   9.250000
# 50%    86.900000  10.600000
# 75%    88.700000  13.400000
# max    92.100000  18.000000

# %%
sns.scatterplot(data=df, x=df['hs_grad'], y=df['poverty'], color='orange');
print('Диаграмма рассеивания')
# Out:
# Диаграмма рассеивания

# %%
r_xy = np.corrcoef(x=df['hs_grad'], y=df['poverty'])[0, 1]
print(f"Коэффициент корреляции равен {r_xy}")
# Out:
# Коэффициент корреляции равен -0.7468582531582506

# %%
R_sq = r_xy ** 2
print(f'Коэффициент детерминации равен {R_sq}')
# Out:
# Коэффициент детерминации равен 0.5577972503105936

# %%
y = df['poverty'].to_numpy().reshape(-1, 1)
X = df['hs_grad'].to_numpy().reshape(-1, 1)

LR = LinearRegression()
model = LR.fit(X, y)

# %%
b0 = model.intercept_[0]
b0 = round(b0, 4)
b0
# Out:
# 64.781

# %%
b1 = model.coef_[0][0]
b1 = round(b1, 4)
b1
# Out:
# -0.6212

# %%
Y = [b0 + b1 * i for i in X]
plt.xlabel('Процент населения имеющий среднее образование')
plt.ylabel('Уровень бедности (%)')
plt.title('Линейная регрессия')
plt.scatter(X, y);
plt.plot(X, Y);

# %%
LR_equation = f'y = {b0} + {b1}X' if b1 > 0 else f'y = {b0} + ({b1})X'
print(f'Уравнение линейной регрессии: {LR_equation}')
# Out:
# Уравнение линейной регрессии: y = 64.781 + (-0.6212)X

# %% [markdown]
# ### С увеличением на 1% количества людей имеющих среднее образование, уровень бедности населения будет уменьшаться примерно на 0.62%
